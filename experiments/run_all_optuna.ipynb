# %%
fixed_task = {'max_iters': 2250, 'eval_iters': 100, 'eval_interval': 100}
fixed_region = {'max_iters': 2250, 'eval_iters': 100, 'eval_interval': 100}
fixed_time = {'max_iters': 500, 'eval_iters': 100, 'eval_interval': 100}
fixed_unified = {'max_iters': 1500, 'eval_iters': 100, 'eval_interval': 100}

# %%
import optuna_variant1
study_v1_task, study_v1_time = optuna_variant1.run(n_trials_task=5, n_trials_time=5, fixed_task=fixed_task, fixed_time=fixed_time)
# Out:
# [I 2026-06-10 17:53:23,798] Using an existing study with name 'v1_task_complete' instead of creating a new one.
# [I 2026-06-10 17:53:44,770] Trial 15 finished with value: 0.5077465176582336 and parameters: {'block_size': 128, 'n_embd': 256, 'n_head': 1, 'n_layer': 1, 'dropout': 0.21220676391927842, 'lr': 0.00022066560361497977, 'weight_decay': 0.08923665854651412, 'batch_size': 128}. Best is trial 15 with value: 0.5077465176582336.
# [I 2026-06-10 17:54:05,255] Trial 16 finished with value: 0.5068166255950928 and parameters: {'block_size': 128, 'n_embd': 256, 'n_head': 1, 'n_layer': 1, 'dropout': 0.26330404850033956, 'lr': 0.00017998188751627928, 'weight_decay': 0.03268227573045302, 'batch_size': 128}. Best is trial 16 with value: 0.5068166255950928.
# [I 2026-06-10 17:54:10,458] Trial 17 finished with value: 0.5071342587471008 and parameters: {'block_size': 128, 'n_embd': 128, 'n_head': 1, 'n_layer': 1, 'dropout': 0.28699508803532064, 'lr': 0.00016198204165286616, 'weight_decay': 0.024265270551047772, 'batch_size': 16}. Best is trial 16 with value: 0.5068166255950928.
# [I 2026-06-10 17:54:29,667] Trial 18 finished with value: 0.5058913230895996 and parameters: {'block_size': 128, 'n_embd': 128, 'n_head': 1, 'n_layer': 8, 'dropout': 0.2806862065932788, 'lr': 0.00015508758254573083, 'weight_decay': 0.022953031519033076, 'batch_size': 16}. Best is trial 18 with value: 0.5058913230895996.
# [I 2026-06-10 17:55:10,838] Trial 19 finished with value: 0.5333291292190552 and parameters: {'block_size': 16, 'n_embd': 128, 'n_head': 4, 'n_layer': 8, 'dropout': 0.2761797068647272, 'lr': 0.00010527942814803428, 'weight_decay': 0.016789414585437576, 'batch_size': 16}. Best is trial 18 with value: 0.5058913230895996.
# [I 2026-06-10 17:55:10,854] Using an existing study with name 'v1_time' instead of creating a new one.
# [V1 TaskTransformer] Best val_loss: 0.5059 | Params: {'block_size': 128, 'n_embd': 128, 'n_head': 1, 'n_layer': 8, 'dropout': 0.2806862065932788, 'lr': 0.00015508758254573083, 'weight_decay': 0.022953031519033076, 'batch_size': 16}
# [I 2026-06-10 17:55:11,873] Trial 5 pruned.
# [I 2026-06-10 17:55:17,616] Trial 6 finished with value: 0.011131662875413895 and parameters: {'block_size': 16, 'n_embd': 128, 'n_head': 4, 'n_layer': 4, 'dropout': 0.2905227852840194, 'lr': 0.00010940574135464267, 'weight_decay': 0.0016709606702031976, 'batch_size': 32}. Best is trial 3 with value: 0.005887134466320276.
# [I 2026-06-10 17:55:18,660] Trial 7 pruned.
# [W 2026-06-10 17:55:20,917] Trial 8 failed with parameters: {'block_size': 16, 'n_embd': 64, 'n_head': 2, 'n_layer': 2, 'dropout': 0.29359714758461897, 'lr': 0.0005004475373350468, 'weight_decay': 0.046848447969928084, 'batch_size': 16} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#   File "/media/DATA/NickZerman/ISI-MasterDegreeThesis/experiments/optuna_variant1.py", line 101, in <lambda>
#     study_time.optimize(lambda trial: objective_time(trial, fixed_time), n_trials=n_trials_time)
#   File "/media/DATA/NickZerman/ISI-MasterDegreeThesis/experiments/optuna_variant1.py", line 72, in objective_time
#     return train_time(model, data, config, device, trial=trial)
#   File "/media/DATA/NickZerman/ISI-MasterDegreeThesis/core/training.py", line 115, in train_time
#     _, loss = model(xd, xt, targets=y)
#   File "/media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/media/DATA/NickZerman/ISI-MasterDegreeThesis/core/models/TimeTransformer.py", line 144, in forward
#     loss = F.mse_loss(time_pred, targets)
#   File "/media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/torch/nn/functional.py", line 3952, in mse_loss
#     return torch._C._nn.mse_loss(
# KeyboardInterrupt
# [W 2026-06-10 17:55:20,918] Trial 8 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import optuna_variant1
# ----> 2 study_v1_task, study_v1_time = optuna_variant1.run(n_trials_task=5, n_trials_time=5, fixed_task=fixed_task, fixed_time=fixed_time)
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/experiments/optuna_variant1.py:101, in run(n_trials_task, n_trials_time, fixed_task, fixed_time)
#      95 print(f"[V1 TaskTransformer] Best val_loss: {study_task.best_value:.4f} | Params: {study_task.best_params}")
#      97 study_time = optuna.create_study(
#      98     direction='minimize', pruner=pruner, study_name='v1_time',
#      99     storage=storage, load_if_exists=True,
#     100 )
# --> 101 study_time.optimize(lambda trial: objective_time(trial, fixed_time), n_trials=n_trials_time)
#     102 print(f"[V1 TimeTransformer] Best val_loss: {study_time.best_value:.4f} | Params: {study_time.best_params}")
#     104 torch.save({
#     105     'TaskTransformer': study_task.best_params,
#     106     'TimeTransformer': study_time.best_params,
#     107 }, DATA_DIR / 'v1_best_params.pt')
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/optuna/study/study.py:516, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     414 def optimize(
#     415     self,
#     416     func: ObjectiveFuncType,
#    (...)
#     423     show_progress_bar: bool = False,
#     424 ) -> None:
#     425     """Optimize an objective function.
#     426
#     427     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     514             If nested invocation of this method occurs.
#     515     """
# --> 516     _optimize(
#     517         study=self,
#     518         func=func,
#     519         n_trials=n_trials,
#     520         timeout=timeout,
#     521         n_jobs=n_jobs,
#     522         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     523         callbacks=callbacks,
#     524         gc_after_trial=gc_after_trial,
#     525         show_progress_bar=show_progress_bar,
#     526     )
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:68, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      66 try:
#      67     if n_jobs == 1:
# ---> 68         _optimize_sequential(
#      69             study,
#      70             func,
#      71             n_trials,
#      72             timeout,
#      73             catch,
#      74             callbacks,
#      75             gc_after_trial,
#      76             reseed_sampler_rng=False,
#      77             time_start=None,
#      78             progress_bar=progress_bar,
#      79         )
#      80     else:
#      81         if n_jobs == -1:
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/experiments/optuna_variant1.py:101, in run.<locals>.<lambda>(trial)
#      95 print(f"[V1 TaskTransformer] Best val_loss: {study_task.best_value:.4f} | Params: {study_task.best_params}")
#      97 study_time = optuna.create_study(
#      98     direction='minimize', pruner=pruner, study_name='v1_time',
#      99     storage=storage, load_if_exists=True,
#     100 )
# --> 101 study_time.optimize(lambda trial: objective_time(trial, fixed_time), n_trials=n_trials_time)
#     102 print(f"[V1 TimeTransformer] Best val_loss: {study_time.best_value:.4f} | Params: {study_time.best_params}")
#     104 torch.save({
#     105     'TaskTransformer': study_task.best_params,
#     106     'TimeTransformer': study_time.best_params,
#     107 }, DATA_DIR / 'v1_best_params.pt')
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/experiments/optuna_variant1.py:72, in objective_time(trial, fixed_time)
#      62 model = TimeTransformer(
#      63     vocab_size_task=vocab_size,
#      64     block_size=config['block_size'],
#    (...)
#      69     separated_regions=False,
#      70 ).to(device)
#      71 try:
# ---> 72     return train_time(model, data, config, device, trial=trial)
#      73 finally:
#      74     del model
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/core/training.py:115, in train_time(model, data, param, device, trial, printing)
#     113 for iter in range(param['max_iters']):
#     114     xd, xt, y = get_batch_time('train', train_data, train_times, val_data, val_times, param['batch_size'], param['block_size'], device)
# --> 115     _, loss = model(xd, xt, targets=y)
#     116     optimizer.zero_grad(set_to_none=True)
#     117     loss.backward()
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/core/models/TimeTransformer.py:144, in TimeTransformer.forward(self, idx_tasks, idx_times, idx_region, targets)
#     142 else:
#     143     targets = targets.unsqueeze(-1).float()
# --> 144     loss = F.mse_loss(time_pred, targets)
#     146 return time_pred, loss
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/torch/nn/functional.py:3952, in mse_loss(input, target, size_average, reduce, reduction, weight)
#    3948         raise ValueError(
#    3949             f"Invalid reduction mode: {reduction}. Expected one of 'none', 'mean', 'sum'."
#    3950         )
#    3951 else:
# -> 3952     return torch._C._nn.mse_loss(
#    3953         expanded_input,
#    3954         expanded_target,
#    3955         # pyrefly: ignore [bad-argument-type]
#    3956         _Reduction.get_enum(reduction),
#    3957     )
#
# KeyboardInterrupt:

# %%
import optuna_variant2
study_v2_task, study_v2_time = optuna_variant2.run(n_trials_task=5, n_trials_time=5, fixed_task=fixed_task, fixed_time=fixed_time)
# Out:
# [I 2026-06-10 16:27:40,192] A new study created in RDB with name: v2_task_separated
# [I 2026-06-10 16:28:00,543] Trial 0 finished with value: 1.329152226448059 and parameters: {'block_size': 64, 'n_embd': 64, 'n_head': 4, 'n_layer': 2, 'dropout': 0.3885466435347109, 'lr': 0.00012237341396785642, 'weight_decay': 0.00011032871078057095, 'batch_size': 64}. Best is trial 0 with value: 1.329152226448059.
# [I 2026-06-10 16:28:24,083] Trial 1 finished with value: 1.2692724466323853 and parameters: {'block_size': 64, 'n_embd': 256, 'n_head': 8, 'n_layer': 2, 'dropout': 0.21176991191585137, 'lr': 0.00030456873216307107, 'weight_decay': 0.0029515331989950814, 'batch_size': 32}. Best is trial 1 with value: 1.2692724466323853.
# [I 2026-06-10 16:29:49,453] Trial 2 finished with value: 1.2646316289901733 and parameters: {'block_size': 64, 'n_embd': 256, 'n_head': 4, 'n_layer': 8, 'dropout': 0.33724321951840486, 'lr': 0.0005008105897258433, 'weight_decay': 0.005700989518584365, 'batch_size': 128}. Best is trial 2 with value: 1.2646316289901733.
# [I 2026-06-10 16:30:08,941] Trial 3 finished with value: 1.2826297283172607 and parameters: {'block_size': 512, 'n_embd': 64, 'n_head': 4, 'n_layer': 1, 'dropout': 0.23568533710254047, 'lr': 0.0008868263099461457, 'weight_decay': 0.0019182846178121258, 'batch_size': 32}. Best is trial 2 with value: 1.2646316289901733.
# [I 2026-06-10 16:31:29,021] Trial 4 finished with value: 1.2623310089111328 and parameters: {'block_size': 128, 'n_embd': 128, 'n_head': 8, 'n_layer': 8, 'dropout': 0.25619672773304464, 'lr': 0.0007503146099757087, 'weight_decay': 0.00015945228054710907, 'batch_size': 64}. Best is trial 4 with value: 1.2623310089111328.
# [I 2026-06-10 16:31:29,072] A new study created in RDB with name: v2_time_separated
# [V2 TaskTransformer] Best val_loss: 1.2623 | Params: {'block_size': 128, 'n_embd': 128, 'n_head': 8, 'n_layer': 8, 'dropout': 0.25619672773304464, 'lr': 0.0007503146099757087, 'weight_decay': 0.00015945228054710907, 'batch_size': 64}
# [I 2026-06-10 16:31:36,437] Trial 0 finished with value: 0.008798147551715374 and parameters: {'block_size': 32, 'n_embd': 64, 'n_head': 4, 'n_layer': 4, 'dropout': 0.3210580591308624, 'lr': 0.0004482489555459783, 'weight_decay': 0.00032875736290617283, 'batch_size': 64}. Best is trial 0 with value: 0.008798147551715374.
# [I 2026-06-10 16:31:39,448] Trial 1 finished with value: 0.01127962488681078 and parameters: {'block_size': 32, 'n_embd': 256, 'n_head': 2, 'n_layer': 2, 'dropout': 0.10862835399287446, 'lr': 0.00043156931442279366, 'weight_decay': 0.0002283963491926424, 'batch_size': 16}. Best is trial 0 with value: 0.008798147551715374.
# [I 2026-06-10 16:31:42,258] Trial 2 finished with value: 0.08358805626630783 and parameters: {'block_size': 16, 'n_embd': 32, 'n_head': 2, 'n_layer': 2, 'dropout': 0.3451073478240824, 'lr': 0.00010080403735973644, 'weight_decay': 0.00010717387703655232, 'batch_size': 8}. Best is trial 0 with value: 0.008798147551715374.
# [I 2026-06-10 16:31:46,497] Trial 3 finished with value: 0.011395837180316448 and parameters: {'block_size': 16, 'n_embd': 64, 'n_head': 2, 'n_layer': 2, 'dropout': 0.28541829248257516, 'lr': 0.000802487157683153, 'weight_decay': 0.005619672849217049, 'batch_size': 64}. Best is trial 0 with value: 0.008798147551715374.
# [I 2026-06-10 16:31:53,820] Trial 4 finished with value: 0.015772711485624313 and parameters: {'block_size': 64, 'n_embd': 128, 'n_head': 4, 'n_layer': 4, 'dropout': 0.3369535736566438, 'lr': 0.00013199534722228555, 'weight_decay': 0.0032464005147868832, 'batch_size': 64}. Best is trial 0 with value: 0.008798147551715374.
# [V2 TimeTransformer] Best val_loss: 0.0088 | Params: {'block_size': 32, 'n_embd': 64, 'n_head': 4, 'n_layer': 4, 'dropout': 0.3210580591308624, 'lr': 0.0004482489555459783, 'weight_decay': 0.00032875736290617283, 'batch_size': 64}

# %%
import optuna_variant3
study_v3_task, study_v3_region, study_v3_time = optuna_variant3.run(n_trials_task=5, n_trials_region=5, n_trials_time=5, fixed_task=fixed_task, fixed_region=fixed_region, fixed_time=fixed_time)
# Out:
# [I 2026-06-10 16:31:53,899] A new study created in RDB with name: v3_task
# [I 2026-06-10 16:32:03,589] Trial 0 finished with value: 0.8025389313697815 and parameters: {'block_size': 64, 'n_embd': 64, 'n_head': 4, 'n_layer': 1, 'dropout': 0.19124902741824557, 'lr': 0.00038882412486462766, 'weight_decay': 0.0012081225069470122, 'batch_size': 32}. Best is trial 0 with value: 0.8025389313697815.
# [I 2026-06-10 16:32:12,897] Trial 1 finished with value: 0.7819116711616516 and parameters: {'block_size': 128, 'n_embd': 128, 'n_head': 2, 'n_layer': 2, 'dropout': 0.1907577827676543, 'lr': 0.0005046009276674678, 'weight_decay': 0.025331622477891284, 'batch_size': 16}. Best is trial 1 with value: 0.7819116711616516.
# [I 2026-06-10 16:32:25,166] Trial 2 finished with value: 0.7982136607170105 and parameters: {'block_size': 128, 'n_embd': 256, 'n_head': 2, 'n_layer': 1, 'dropout': 0.2996960206199738, 'lr': 0.0004287888553147941, 'weight_decay': 0.00337157108630693, 'batch_size': 64}. Best is trial 1 with value: 0.7819116711616516.
# [I 2026-06-10 16:32:37,396] Trial 3 finished with value: 0.7833309769630432 and parameters: {'block_size': 128, 'n_embd': 64, 'n_head': 2, 'n_layer': 2, 'dropout': 0.2978420489782332, 'lr': 0.0005057211518482691, 'weight_decay': 0.00027371624002711794, 'batch_size': 64}. Best is trial 1 with value: 0.7819116711616516.
# [I 2026-06-10 16:33:09,593] Trial 4 finished with value: 0.7703585028648376 and parameters: {'block_size': 256, 'n_embd': 256, 'n_head': 8, 'n_layer': 2, 'dropout': 0.32596268205095114, 'lr': 0.0009537244845963682, 'weight_decay': 0.0010748337536528587, 'batch_size': 32}. Best is trial 4 with value: 0.7703585028648376.
# [I 2026-06-10 16:33:09,619] A new study created in RDB with name: v3_region
# [V3 TaskTransformer] Best val_loss: 0.7704 | Params: {'block_size': 256, 'n_embd': 256, 'n_head': 8, 'n_layer': 2, 'dropout': 0.32596268205095114, 'lr': 0.0009537244845963682, 'weight_decay': 0.0010748337536528587, 'batch_size': 32}
# [I 2026-06-10 16:33:18,328] Trial 0 finished with value: 0.009287831373512745 and parameters: {'block_size': 256, 'n_embd': 64, 'n_head': 2, 'n_layer': 1, 'dropout': 0.10691096220081137, 'lr': 0.00011547901094214442, 'weight_decay': 0.003179449952474423, 'batch_size': 32}. Best is trial 0 with value: 0.009287831373512745.
# [I 2026-06-10 16:33:25,093] Trial 1 finished with value: 0.010688398033380508 and parameters: {'block_size': 64, 'n_embd': 64, 'n_head': 2, 'n_layer': 1, 'dropout': 0.35879103034209914, 'lr': 0.00014949729662930059, 'weight_decay': 0.03288430373530262, 'batch_size': 16}. Best is trial 0 with value: 0.009287831373512745.
# [I 2026-06-10 16:33:31,913] Trial 2 finished with value: 0.0039040325209498405 and parameters: {'block_size': 128, 'n_embd': 128, 'n_head': 2, 'n_layer': 1, 'dropout': 0.19849085390080007, 'lr': 0.00010641935833244885, 'weight_decay': 0.00029930870359771484, 'batch_size': 16}. Best is trial 2 with value: 0.0039040325209498405.
# [I 2026-06-10 16:33:45,639] Trial 3 finished with value: 0.0031626191921532154 and parameters: {'block_size': 128, 'n_embd': 64, 'n_head': 8, 'n_layer': 1, 'dropout': 0.3231806006966584, 'lr': 0.00034436168033957824, 'weight_decay': 0.06254817551015851, 'batch_size': 32}. Best is trial 3 with value: 0.0031626191921532154.
# [I 2026-06-10 16:33:55,301] Trial 4 finished with value: 0.010999368503689766 and parameters: {'block_size': 64, 'n_embd': 64, 'n_head': 2, 'n_layer': 2, 'dropout': 0.25475096493268046, 'lr': 0.00012446503380536257, 'weight_decay': 0.0002331127166951481, 'batch_size': 16}. Best is trial 3 with value: 0.0031626191921532154.
# [I 2026-06-10 16:33:55,326] A new study created in RDB with name: v3_time_separated
# [V3 RegionTransformer] Best val_loss: 0.0032 | Params: {'block_size': 128, 'n_embd': 64, 'n_head': 8, 'n_layer': 1, 'dropout': 0.3231806006966584, 'lr': 0.00034436168033957824, 'weight_decay': 0.06254817551015851, 'batch_size': 32}
# [I 2026-06-10 16:33:57,068] Trial 0 finished with value: 0.03834303468465805 and parameters: {'block_size': 64, 'n_embd': 256, 'n_head': 2, 'n_layer': 1, 'dropout': 0.15846482311613969, 'lr': 0.0007563457348599504, 'weight_decay': 0.014415489404577635, 'batch_size': 8}. Best is trial 0 with value: 0.03834303468465805.
# [I 2026-06-10 16:34:01,569] Trial 1 finished with value: 0.0143673000857234 and parameters: {'block_size': 32, 'n_embd': 32, 'n_head': 2, 'n_layer': 4, 'dropout': 0.23358391102109002, 'lr': 0.0009646837614548934, 'weight_decay': 0.00016140486397043832, 'batch_size': 32}. Best is trial 1 with value: 0.0143673000857234.
# [I 2026-06-10 16:34:04,196] Trial 2 finished with value: 0.05099263787269592 and parameters: {'block_size': 64, 'n_embd': 128, 'n_head': 2, 'n_layer': 2, 'dropout': 0.3780103265425171, 'lr': 0.00010581642262627625, 'weight_decay': 0.05962765313842518, 'batch_size': 16}. Best is trial 1 with value: 0.0143673000857234.
# [I 2026-06-10 16:34:07,184] Trial 3 finished with value: 0.03643888607621193 and parameters: {'block_size': 32, 'n_embd': 128, 'n_head': 8, 'n_layer': 1, 'dropout': 0.21539848074784373, 'lr': 0.00016661613013933528, 'weight_decay': 0.0971818686995387, 'batch_size': 8}. Best is trial 1 with value: 0.0143673000857234.
# [I 2026-06-10 16:34:12,390] Trial 4 finished with value: 0.05505231395363808 and parameters: {'block_size': 64, 'n_embd': 64, 'n_head': 8, 'n_layer': 2, 'dropout': 0.3979443925563726, 'lr': 0.00017763516403779202, 'weight_decay': 0.006368590167215341, 'batch_size': 16}. Best is trial 1 with value: 0.0143673000857234.
# [V3 TimeTransformer] Best val_loss: 0.0144 | Params: {'block_size': 32, 'n_embd': 32, 'n_head': 2, 'n_layer': 4, 'dropout': 0.23358391102109002, 'lr': 0.0009646837614548934, 'weight_decay': 0.00016140486397043832, 'batch_size': 32}

# %%
import optuna_variant4
study_v4 = optuna_variant4.run(n_trials=2, fixed_unified=fixed_unified)
# Out:
# [I 2026-06-10 16:37:25,968] Using an existing study with name 'v4_unified' instead of creating a new one.
# [I 2026-06-10 16:37:31,374] Trial 10 pruned.
# [I 2026-06-10 16:37:45,811] Trial 11 pruned.
# [V4 UnifiedTransformer] Best val_loss: 0.4386 | Params: {'block_size': 256, 'n_embd': 128, 'n_head': 2, 'n_layer': 2, 'dropout': 0.11575443874833989, 'lr': 0.0009742284161790867, 'weight_decay': 0.004911185884659166, 'batch_size': 128}

# %%
import optuna_variant5
study_v5_task, study_v5_unified = optuna_variant5.run(n_trials_task=5, n_trials_unified=5, fixed_task=fixed_task, fixed_unified=fixed_unified)
# Out:
# [I 2026-06-10 16:37:45,848] A new study created in RDB with name: v5_task
# [I 2026-06-10 16:37:54,159] Trial 0 finished with value: 0.9719161987304688 and parameters: {'block_size': 64, 'n_embd': 64, 'n_head': 4, 'n_layer': 1, 'dropout': 0.3650204046914195, 'lr': 0.00010429344419192012, 'weight_decay': 0.0009043638049617949, 'batch_size': 16}. Best is trial 0 with value: 0.9719161987304688.
# [I 2026-06-10 16:38:37,938] Trial 1 finished with value: 0.7917872071266174 and parameters: {'block_size': 256, 'n_embd': 128, 'n_head': 8, 'n_layer': 4, 'dropout': 0.35278565747706475, 'lr': 0.00017562211822343918, 'weight_decay': 0.015225513022808028, 'batch_size': 32}. Best is trial 1 with value: 0.7917872071266174.
# [I 2026-06-10 16:38:59,406] Trial 2 finished with value: 0.8009201288223267 and parameters: {'block_size': 128, 'n_embd': 256, 'n_head': 8, 'n_layer': 2, 'dropout': 0.3886521064423875, 'lr': 0.00020338875950052628, 'weight_decay': 0.0008371329967045287, 'batch_size': 16}. Best is trial 1 with value: 0.7917872071266174.
# [I 2026-06-10 16:39:37,967] Trial 3 finished with value: 0.7698405385017395 and parameters: {'block_size': 256, 'n_embd': 256, 'n_head': 2, 'n_layer': 4, 'dropout': 0.2855278095982314, 'lr': 0.0006736296806978664, 'weight_decay': 0.016711667856893302, 'batch_size': 32}. Best is trial 3 with value: 0.7698405385017395.
# [I 2026-06-10 16:40:15,772] Trial 4 finished with value: 0.8001610040664673 and parameters: {'block_size': 128, 'n_embd': 64, 'n_head': 8, 'n_layer': 4, 'dropout': 0.3965792302260989, 'lr': 0.00032091140925125594, 'weight_decay': 0.0001648667117312427, 'batch_size': 32}. Best is trial 3 with value: 0.7698405385017395.
# [I 2026-06-10 16:40:15,796] A new study created in RDB with name: v5_unified_onlyregion
# [V5 TaskTransformer] Best val_loss: 0.7698 | Params: {'block_size': 256, 'n_embd': 256, 'n_head': 2, 'n_layer': 4, 'dropout': 0.2855278095982314, 'lr': 0.0006736296806978664, 'weight_decay': 0.016711667856893302, 'batch_size': 32}
# [I 2026-06-10 16:40:31,480] Trial 0 finished with value: -0.9556970000267029 and parameters: {'block_size': 128, 'n_embd': 256, 'n_head': 8, 'n_layer': 2, 'dropout': 0.31439982186508236, 'lr': 0.00042853792197847414, 'weight_decay': 0.035367987569550174, 'batch_size': 16}. Best is trial 0 with value: -0.9556970000267029.
# [I 2026-06-10 16:40:40,957] Trial 1 finished with value: -0.40155142545700073 and parameters: {'block_size': 128, 'n_embd': 256, 'n_head': 4, 'n_layer': 1, 'dropout': 0.2775427917738719, 'lr': 0.00018141040157877833, 'weight_decay': 0.09537519038834325, 'batch_size': 32}. Best is trial 0 with value: -0.9556970000267029.
# [I 2026-06-10 16:48:45,708] Trial 2 finished with value: -1.240754246711731 and parameters: {'block_size': 512, 'n_embd': 128, 'n_head': 8, 'n_layer': 8, 'dropout': 0.2697831884301453, 'lr': 0.0006288243236437196, 'weight_decay': 0.008099909106388435, 'batch_size': 64}. Best is trial 2 with value: -1.240754246711731.
# [I 2026-06-10 16:49:09,318] Trial 3 finished with value: -0.5284266471862793 and parameters: {'block_size': 128, 'n_embd': 128, 'n_head': 4, 'n_layer': 2, 'dropout': 0.19170683480381026, 'lr': 0.00023264118909015614, 'weight_decay': 0.0003303565993560166, 'batch_size': 128}. Best is trial 2 with value: -1.240754246711731.
# [I 2026-06-10 16:49:32,803] Trial 4 finished with value: -1.6138663291931152 and parameters: {'block_size': 64, 'n_embd': 256, 'n_head': 4, 'n_layer': 4, 'dropout': 0.2751098651827382, 'lr': 0.0007273237093665622, 'weight_decay': 0.001535386769449095, 'batch_size': 64}. Best is trial 4 with value: -1.6138663291931152.
# [V5 UnifiedTransformer] Best val_loss: -1.6139 | Params: {'block_size': 64, 'n_embd': 256, 'n_head': 4, 'n_layer': 4, 'dropout': 0.2751098651827382, 'lr': 0.0007273237093665622, 'weight_decay': 0.001535386769449095, 'batch_size': 64}

# %%
import optuna_variant6
study_v6 = optuna_variant6.run(n_trials=5, fixed_unified=fixed_unified)
# Out:
# [I 2026-06-10 16:49:32,875] A new study created in RDB with name: v6_unified_taskregion
# [I 2026-06-10 16:50:22,442] Trial 0 finished with value: 0.35757187008857727 and parameters: {'block_size': 64, 'n_embd': 128, 'n_head': 8, 'n_layer': 8, 'dropout': 0.32705229941353126, 'lr': 0.0005837670897381101, 'weight_decay': 0.0005917862713355716, 'batch_size': 16}. Best is trial 0 with value: 0.35757187008857727.
# [I 2026-06-10 16:50:35,463] Trial 1 finished with value: 0.7836605310440063 and parameters: {'block_size': 64, 'n_embd': 64, 'n_head': 2, 'n_layer': 4, 'dropout': 0.3598863279901149, 'lr': 0.0001320844237648475, 'weight_decay': 0.00030043145439297364, 'batch_size': 32}. Best is trial 0 with value: 0.35757187008857727.
# [I 2026-06-10 16:50:45,660] Trial 2 finished with value: 0.5325048565864563 and parameters: {'block_size': 128, 'n_embd': 256, 'n_head': 4, 'n_layer': 2, 'dropout': 0.395458456337049, 'lr': 0.0003398748155548375, 'weight_decay': 0.09701384206173115, 'batch_size': 16}. Best is trial 0 with value: 0.35757187008857727.
# [I 2026-06-10 16:51:08,910] Trial 3 finished with value: 0.6813294887542725 and parameters: {'block_size': 128, 'n_embd': 64, 'n_head': 2, 'n_layer': 8, 'dropout': 0.18055284771367902, 'lr': 0.00018958975200345887, 'weight_decay': 0.0934282443998003, 'batch_size': 64}. Best is trial 0 with value: 0.35757187008857727.
# [I 2026-06-10 16:52:01,382] Trial 4 finished with value: 0.4174623191356659 and parameters: {'block_size': 64, 'n_embd': 64, 'n_head': 8, 'n_layer': 8, 'dropout': 0.297863749473331, 'lr': 0.0004917831715481448, 'weight_decay': 0.00014647327637333155, 'batch_size': 64}. Best is trial 0 with value: 0.35757187008857727.
# [V6 UnifiedTransformer] Best val_loss: 0.3576 | Params: {'block_size': 64, 'n_embd': 128, 'n_head': 8, 'n_layer': 8, 'dropout': 0.32705229941353126, 'lr': 0.0005837670897381101, 'weight_decay': 0.0005917862713355716, 'batch_size': 16}

# %%
print('=== RIEPILOGO BEST VAL LOSS ===')
print(f'V1  TaskTransformer:   {study_v1_task.best_value:.4f}')
print(f'V1  TimeTransformer:   {study_v1_time.best_value:.4f}')
print(f'V2  TaskTransformer:   {study_v2_task.best_value:.4f}')
print(f'V2  TimeTransformer:   {study_v2_time.best_value:.4f}')
print(f'V3  TaskTransformer:   {study_v3_task.best_value:.4f}')
print(f'V3  RegionTransformer: {study_v3_region.best_value:.4f}')
print(f'V3  TimeTransformer:   {study_v3_time.best_value:.4f}')
print(f'V4  UnifiedTransformer:{study_v4.best_value:.4f}')
print(f'V5  TaskTransformer:   {study_v5_task.best_value:.4f}')
print(f'V5  UnifiedTransformer:{study_v5_unified.best_value:.4f}')
print(f'V6  UnifiedTransformer:{study_v6.best_value:.4f}')
# Out:
# === RIEPILOGO BEST VAL LOSS ===
# V1  TaskTransformer:   0.7682
# V1  TimeTransformer:   0.0059
# V2  TaskTransformer:   1.2623
# V2  TimeTransformer:   0.0088
# V3  TaskTransformer:   0.7704
# V3  RegionTransformer: 0.0032
# V3  TimeTransformer:   0.0144
# V4  UnifiedTransformer:0.4386
# V5  TaskTransformer:   0.7698
# V5  UnifiedTransformer:-1.6139
# V6  UnifiedTransformer:0.3576
