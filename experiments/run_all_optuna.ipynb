# %%
from config import RESULTS_DIR

import sys
sys.path.insert(0, 'experiments')

import os
db_path = RESULTS_DIR / "optuna.db"
if db_path.exists():
    os.remove(db_path)

import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)

fixed_task    = {'max_iters': 1000, 'eval_iters': 100, 'eval_interval': 100}
fixed_region  = {'max_iters': 1000, 'eval_iters': 100, 'eval_interval': 100}
fixed_time    = {'max_iters': 500,  'eval_iters': 100, 'eval_interval': 100}
fixed_unified = {'max_iters': 700,  'eval_iters': 100, 'eval_interval': 100}
data_file = "prepared_data_sepsis.pt"

# %%
import optuna_variant1
study_v1_task, study_v1_time = optuna_variant1.run(n_trials_task=50, n_trials_time=50, fixed_task=fixed_task, fixed_time=fixed_time, data_file=data_file)
# Out:
# [V1 TaskTransformer] Best val_loss: 0.6476 | Params: {'block_size': 16, 'n_embd': 128, 'n_head': 4, 'n_layer': 8, 'dropout': 0.5072853103731644, 'lr': 0.0002649331687441642, 'weight_decay': 0.0164585692403819, 'batch_size': 64}

# %%
import gc, torch; gc.collect(); torch.cuda.empty_cache()

# %%
import optuna_variant2
study_v2_task, study_v2_time = optuna_variant2.run(n_trials_task=50, n_trials_time=50, fixed_task=fixed_task, fixed_time=fixed_time, data_file=data_file)

# %%
import gc, torch; gc.collect(); torch.cuda.empty_cache()

# %%
import optuna_variant3
study_v3_task, study_v3_region, study_v3_time = optuna_variant3.run(n_trials_task=50, n_trials_region=50, n_trials_time=50, fixed_task=fixed_task, fixed_region=fixed_region, fixed_time=fixed_time, data_file=data_file)

# %%
import gc, torch; gc.collect(); torch.cuda.empty_cache()

# %%
import optuna_variant4
study_v4 = optuna_variant4.run(n_trials=50, fixed_unified=fixed_unified, data_file=data_file)

# %%
import gc, torch; gc.collect(); torch.cuda.empty_cache()

# %%
import optuna_variant5
study_v5_task, study_v5_unified = optuna_variant5.run(n_trials_task=50, n_trials_unified=50, fixed_task=fixed_task, fixed_unified=fixed_unified, data_file=data_file)

# %%
import gc, torch; gc.collect(); torch.cuda.empty_cache()

# %%
import optuna_variant6
study_v6 = optuna_variant6.run(n_trials=50, fixed_unified=fixed_unified, data_file=data_file)

# %%
print('=== RIEPILOGO BEST VAL LOSS ===')
print(f'V1  TaskTransformer:   {study_v1_task.best_value:.4f}')
print(f'V1  TimeTransformer:   {study_v1_time.best_value:.4f}')
print(f'V2  TaskTransformer:   {study_v2_task.best_value:.4f}')
print(f'V2  TimeTransformer:   {study_v2_time.best_value:.4f}')
print(f'V3  TaskTransformer:   {study_v3_task.best_value:.4f}')
print(f'V3  RegionTransformer: {study_v3_region.best_value:.4f}')
print(f'V3  TimeTransformer:   {study_v3_time.best_value:.4f}')
print(f'V4  UnifiedTransformer:{study_v4.best_value:.4f}')
print(f'V5  TaskTransformer:   {study_v5_task.best_value:.4f}')
print(f'V5  UnifiedTransformer:{study_v5_unified.best_value:.4f}')
print(f'V6  UnifiedTransformer:{study_v6.best_value:.4f}')
