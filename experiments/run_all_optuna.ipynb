# %%
from config import RESULTS_DIR

import sys
sys.path.insert(0, 'experiments')

import os
db_path = RESULTS_DIR / "optuna.db"
if db_path.exists():
    os.remove(db_path)

import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)

data_file = "prepared_data.pt"
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import optuna_variant1
study_v1_task, study_v1_time = optuna_variant1.run(n_trials_task=1, n_trials_time=1, data_file=data_file)
# Out:
# [W 2026-06-16 16:39:15,375] Trial 2 failed with parameters: {'block_size': 32, 'n_embd': 256, 'n_head': 1, 'n_layer': 8, 'dropout': 0.3570988524100311, 'lr': 0.0006847251862095586, 'weight_decay': 0.08780178547658632, 'batch_size': 32} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#   File "/media/DATA/NickZerman/ISI-MasterDegreeThesis/experiments/optuna_variant1.py", line 93, in <lambda>
#     study_task.optimize(lambda trial: objective_task(trial, fixed_task), n_trials=n_trials_task)
#   File "/media/DATA/NickZerman/ISI-MasterDegreeThesis/experiments/optuna_variant1.py", line 50, in objective_task
#     return train_task(model, data, config, device, data_key='complete', trial=trial)
#   File "/media/DATA/NickZerman/ISI-MasterDegreeThesis/core/training.py", line 29, in train_task
#     loss.backward() #Errore per neurone
#   File "/media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/torch/_tensor.py", line 631, in backward
#     torch.autograd.backward(
#   File "/media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/torch/autograd/__init__.py", line 381, in backward
#     _engine_run_backward(
#   File "/media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/torch/autograd/graph.py", line 869, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# KeyboardInterrupt
# [W 2026-06-16 16:39:15,376] Trial 2 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 import optuna_variant1
# ----> 2 study_v1_task, study_v1_time = optuna_variant1.run(n_trials_task=5, n_trials_time=5, fixed_task=fixed_task, fixed_time=fixed_time, data_file=data_file)
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/experiments/optuna_variant1.py:93, in run(n_trials_task, n_trials_time, fixed_task, fixed_time, data_file)
#      87 DATA_DIR.mkdir(parents=True, exist_ok=True)
#      89 study_task = optuna.create_study(
#      90     direction='minimize', pruner=pruner, study_name='v1_task_complete',
#      91     storage=storage, load_if_exists=True,
#      92 )
# ---> 93 study_task.optimize(lambda trial: objective_task(trial, fixed_task), n_trials=n_trials_task)
#      94 print(f"[V1 TaskTransformer] Best val_loss: {study_task.best_value:.4f} | Params: {study_task.best_params}")
#      96 study_time = optuna.create_study(
#      97     direction='minimize', pruner=pruner, study_name='v1_time',
#      98     storage=storage, load_if_exists=True,
#      99 )
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/optuna/study/study.py:516, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     414 def optimize(
#     415     self,
#     416     func: ObjectiveFuncType,
#    (...)
#     423     show_progress_bar: bool = False,
#     424 ) -> None:
#     425     """Optimize an objective function.
#     426
#     427     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     514             If nested invocation of this method occurs.
#     515     """
# --> 516     _optimize(
#     517         study=self,
#     518         func=func,
#     519         n_trials=n_trials,
#     520         timeout=timeout,
#     521         n_jobs=n_jobs,
#     522         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     523         callbacks=callbacks,
#     524         gc_after_trial=gc_after_trial,
#     525         show_progress_bar=show_progress_bar,
#     526     )
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:68, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      66 try:
#      67     if n_jobs == 1:
# ---> 68         _optimize_sequential(
#      69             study,
#      70             func,
#      71             n_trials,
#      72             timeout,
#      73             catch,
#      74             callbacks,
#      75             gc_after_trial,
#      76             reseed_sampler_rng=False,
#      77             time_start=None,
#      78             progress_bar=progress_bar,
#      79         )
#      80     else:
#      81         if n_jobs == -1:
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/experiments/optuna_variant1.py:93, in run.<locals>.<lambda>(trial)
#      87 DATA_DIR.mkdir(parents=True, exist_ok=True)
#      89 study_task = optuna.create_study(
#      90     direction='minimize', pruner=pruner, study_name='v1_task_complete',
#      91     storage=storage, load_if_exists=True,
#      92 )
# ---> 93 study_task.optimize(lambda trial: objective_task(trial, fixed_task), n_trials=n_trials_task)
#      94 print(f"[V1 TaskTransformer] Best val_loss: {study_task.best_value:.4f} | Params: {study_task.best_params}")
#      96 study_time = optuna.create_study(
#      97     direction='minimize', pruner=pruner, study_name='v1_time',
#      98     storage=storage, load_if_exists=True,
#      99 )
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/experiments/optuna_variant1.py:50, in run.<locals>.objective_task(trial, fixed_task)
#      41 model = TaskTransformer(
#      42     task_vocab_size=vocab_size,
#      43     block_size=config['block_size'],
#    (...)
#      47     n_layer=config['n_layer'],
#      48 ).to(device)
#      49 try:
# ---> 50     return train_task(model, data, config, device, data_key='complete', trial=trial)
#      51 finally:
#      52     del model
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/core/training.py:29, in train_task(model, data, param, device, data_key, trial, printing)
#      27 logits, loss = model(xb, targets_task=yb) # Esegue il forward e predice
#      28 optimizer.zero_grad(set_to_none=True) # Reset gradienti (puliamo i calcoli del giro precedente)
# ---> 29 loss.backward() #Errore per neurone
#      30 optimizer.step() # Aggiorna automaticamente i pesi per sbagliare di meno al giro dopo
#      32 if use_swa and iter >= swa_start:
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/torch/_tensor.py:631, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     621 if has_torch_function_unary(self):
#     622     return handle_torch_function(
#     623         Tensor.backward,
#     624         (self,),
#    (...)
#     629         inputs=inputs,
#     630     )
# --> 631 torch.autograd.backward(
#     632     self, gradient, retain_graph, create_graph, inputs=inputs
#     633 )
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/torch/autograd/__init__.py:381, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     376     retain_graph = create_graph
#     378 # The reason we repeat the same comment below is that
#     379 # some Python versions print out the first line of a multi-line function
#     380 # calls in the traceback and some print out the last line
# --> 381 _engine_run_backward(
#     382     tensors,
#     383     grad_tensors_,
#     384     retain_graph,
#     385     create_graph,
#     386     inputs_tuple,
#     387     allow_unreachable=True,
#     388     accumulate_grad=True,
#     389 )
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/torch/autograd/graph.py:869, in _engine_run_backward(t_outputs, *args, **kwargs)
#     867     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     868 try:
# --> 869     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     870         t_outputs, *args, **kwargs
#     871     )  # Calls into the C++ engine to run the backward pass
#     872 finally:
#     873     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
import gc, torch; gc.collect(); torch.cuda.empty_cache()

# %%
import optuna_variant2
study_v2_task, study_v2_time = optuna_variant2.run(n_trials_task=1, n_trials_time=1, data_file=data_file)

# %%
import gc, torch; gc.collect(); torch.cuda.empty_cache()

# %%
import optuna_variant3
study_v3_task, study_v3_region, study_v3_time = optuna_variant3.run(n_trials_task=1, n_trials_region=1, n_trials_time=1, data_file=data_file)

# %%
import gc, torch; gc.collect(); torch.cuda.empty_cache()

# %%
import optuna_variant4
study_v4 = optuna_variant4.run(n_trials=1, data_file=data_file)

# %%
import gc, torch; gc.collect(); torch.cuda.empty_cache()

# %%
import optuna_variant5
study_v5_task, study_v5_unified = optuna_variant5.run(n_trials_task=1, n_trials_unified=1, data_file=data_file)

# %%
import gc, torch; gc.collect(); torch.cuda.empty_cache()

# %%
import optuna_variant6
study_v6 = optuna_variant6.run(n_trials=1, data_file=data_file)

# %%
print('=== RIEPILOGO BEST VAL LOSS ===')
print(f'V1  TaskTransformer:   {study_v1_task.best_value:.4f}')
print(f'V1  TimeTransformer:   {study_v1_time.best_value:.4f}')
print(f'V2  TaskTransformer:   {study_v2_task.best_value:.4f}')
print(f'V2  TimeTransformer:   {study_v2_time.best_value:.4f}')
print(f'V3  TaskTransformer:   {study_v3_task.best_value:.4f}')
print(f'V3  RegionTransformer: {study_v3_region.best_value:.4f}')
print(f'V3  TimeTransformer:   {study_v3_time.best_value:.4f}')
print(f'V4  UnifiedTransformer:{study_v4.best_value:.4f}')
print(f'V5  TaskTransformer:   {study_v5_task.best_value:.4f}')
print(f'V5  UnifiedTransformer:{study_v5_unified.best_value:.4f}')
print(f'V6  UnifiedTransformer:{study_v6.best_value:.4f}')
