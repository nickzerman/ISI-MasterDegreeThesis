# %%
from experiments import optuna_variant1
study_v1_task, study_v1_time = optuna_variant1.run(n_trials_task=30, n_trials_time=5)
# Out:
# [I 2026-06-08 16:46:36,360] A new study created in RDB with name: v1_task_complete
# [I 2026-06-08 16:47:32,982] Trial 0 finished with value: 0.7686037421226501 and parameters: {'block_size': 256, 'n_embd': 256, 'n_head': 4, 'n_layer': 8, 'dropout': 0.5828532224352141, 'lr': 0.0009648825158439, 'batch_size': 16}. Best is trial 0 with value: 0.7686037421226501.
# [I 2026-06-08 16:48:00,120] Trial 1 finished with value: 0.7745386362075806 and parameters: {'block_size': 64, 'n_embd': 256, 'n_head': 2, 'n_layer': 8, 'dropout': 0.5086392892896159, 'lr': 0.0005852874842205563, 'batch_size': 16}. Best is trial 0 with value: 0.7686037421226501.
# [I 2026-06-08 16:49:13,984] Trial 2 finished with value: 0.7915469408035278 and parameters: {'block_size': 32, 'n_embd': 32, 'n_head': 8, 'n_layer': 8, 'dropout': 0.26456915734410213, 'lr': 0.0004830819323419072, 'batch_size': 64}. Best is trial 0 with value: 0.7686037421226501.
# [I 2026-06-08 16:50:05,468] Trial 3 finished with value: 0.7682005167007446 and parameters: {'block_size': 256, 'n_embd': 256, 'n_head': 4, 'n_layer': 1, 'dropout': 0.49106865871119804, 'lr': 0.0007481568094203907, 'batch_size': 128}. Best is trial 3 with value: 0.7682005167007446.
# [I 2026-06-08 16:50:20,362] Trial 4 finished with value: 0.7924695014953613 and parameters: {'block_size': 32, 'n_embd': 32, 'n_head': 4, 'n_layer': 1, 'dropout': 0.4491786808622813, 'lr': 0.0003837354471262389, 'batch_size': 128}. Best is trial 3 with value: 0.7682005167007446.
# [I 2026-06-08 16:50:21,690] Trial 5 pruned.
# [I 2026-06-08 16:50:24,486] Trial 6 pruned.
# [I 2026-06-08 16:50:26,736] Trial 7 pruned.
# [I 2026-06-08 16:50:28,301] Trial 8 pruned.
# [I 2026-06-08 16:50:30,866] Trial 9 pruned.
# [I 2026-06-08 16:50:31,917] Trial 10 pruned.
# [I 2026-06-08 16:50:41,063] Trial 11 finished with value: 0.7696790099143982 and parameters: {'block_size': 256, 'n_embd': 256, 'n_head': 4, 'n_layer': 1, 'dropout': 0.4432564818457161, 'lr': 0.0009930100103776125, 'batch_size': 16}. Best is trial 3 with value: 0.7682005167007446.
# [I 2026-06-08 16:52:13,435] Trial 12 finished with value: 0.7660701870918274 and parameters: {'block_size': 256, 'n_embd': 256, 'n_head': 4, 'n_layer': 2, 'dropout': 0.5910533043336559, 'lr': 0.000812052710267525, 'batch_size': 128}. Best is trial 12 with value: 0.7660701870918274.
# [I 2026-06-08 16:53:49,085] Trial 13 finished with value: 0.7665356397628784 and parameters: {'block_size': 256, 'n_embd': 256, 'n_head': 4, 'n_layer': 2, 'dropout': 0.599871193389482, 'lr': 0.0007111142934017094, 'batch_size': 128}. Best is trial 12 with value: 0.7660701870918274.
# [I 2026-06-08 16:53:50,955] Trial 14 pruned.
# [I 2026-06-08 16:54:04,904] Trial 15 pruned.
# [I 2026-06-08 16:54:30,170] Trial 16 finished with value: 0.7698736786842346 and parameters: {'block_size': 64, 'n_embd': 256, 'n_head': 4, 'n_layer': 2, 'dropout': 0.5299361224485046, 'lr': 0.00037681448504561354, 'batch_size': 128}. Best is trial 12 with value: 0.7660701870918274.
# [I 2026-06-08 16:54:33,019] Trial 17 pruned.
# [I 2026-06-08 16:54:41,393] Trial 18 pruned.
# [I 2026-06-08 16:54:42,554] Trial 19 pruned.
# [I 2026-06-08 16:54:45,523] Trial 20 pruned.
# [I 2026-06-08 16:55:37,233] Trial 21 finished with value: 0.7692121863365173 and parameters: {'block_size': 256, 'n_embd': 256, 'n_head': 4, 'n_layer': 1, 'dropout': 0.48845292410973523, 'lr': 0.0007591114385564657, 'batch_size': 128}. Best is trial 12 with value: 0.7660701870918274.
# [I 2026-06-08 16:56:30,123] Trial 22 finished with value: 0.767687201499939 and parameters: {'block_size': 256, 'n_embd': 256, 'n_head': 4, 'n_layer': 1, 'dropout': 0.4181144023344884, 'lr': 0.0008087243179294953, 'batch_size': 128}. Best is trial 12 with value: 0.7660701870918274.
# [W 2026-06-08 16:57:05,545] Trial 23 failed with parameters: {'block_size': 256, 'n_embd': 256, 'n_head': 4, 'n_layer': 4, 'dropout': 0.21135620413872194, 'lr': 0.0006225081105816016, 'batch_size': 128} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#   File "/media/DATA/NickZerman/ISI-MasterDegreeThesis/experiments/optuna_variant1.py", line 46, in objective_task
#     return train_task(model, data, config, device, data_key='complete', trial=trial)
#   File "/media/DATA/NickZerman/ISI-MasterDegreeThesis/core/training.py", line 13, in train_task
#     xb, yb = get_batch_task('train', train_data, val_data, param['batch_size'], param['block_size'], device) # Pesco tracce
#   File "/media/DATA/NickZerman/ISI-MasterDegreeThesis/utils/transformer_utils.py", line 25, in get_batch_task
#     x = torch.stack([data[i:i+block_size] for i in ix])
# KeyboardInterrupt
# [W 2026-06-08 16:57:05,546] Trial 23 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 from experiments import optuna_variant1
# ----> 2 study_v1_task, study_v1_time = optuna_variant1.run(n_trials_task=50, n_trials_time=5)
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/experiments/optuna_variant1.py:91, in run(n_trials_task, n_trials_time)
#      85 os.makedirs('data', exist_ok=True)
#      87 study_task = optuna.create_study(
#      88     direction='minimize', pruner=pruner, study_name='v1_task_complete',
#      89     storage=storage, load_if_exists=True,
#      90 )
# ---> 91 study_task.optimize(objective_task, n_trials=n_trials_task)
#      92 print(f"[V1 TaskTransformer] Best val_loss: {study_task.best_value:.4f} | Params: {study_task.best_params}")
#      94 study_time = optuna.create_study(
#      95     direction='minimize', pruner=pruner, study_name='v1_time',
#      96     storage=storage, load_if_exists=True,
#      97 )
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/optuna/study/study.py:516, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     414 def optimize(
#     415     self,
#     416     func: ObjectiveFuncType,
#    (...)
#     423     show_progress_bar: bool = False,
#     424 ) -> None:
#     425     """Optimize an objective function.
#     426
#     427     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     514             If nested invocation of this method occurs.
#     515     """
# --> 516     _optimize(
#     517         study=self,
#     518         func=func,
#     519         n_trials=n_trials,
#     520         timeout=timeout,
#     521         n_jobs=n_jobs,
#     522         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     523         callbacks=callbacks,
#     524         gc_after_trial=gc_after_trial,
#     525         show_progress_bar=show_progress_bar,
#     526     )
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:68, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      66 try:
#      67     if n_jobs == 1:
# ---> 68         _optimize_sequential(
#      69             study,
#      70             func,
#      71             n_trials,
#      72             timeout,
#      73             catch,
#      74             callbacks,
#      75             gc_after_trial,
#      76             reseed_sampler_rng=False,
#      77             time_start=None,
#      78             progress_bar=progress_bar,
#      79         )
#      80     else:
#      81         if n_jobs == -1:
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/experiments/optuna_variant1.py:46, in objective_task(trial)
#      37 model = TaskTransformer(
#      38     task_vocab_size=vocab_size,
#      39     block_size=config['block_size'],
#    (...)
#      43     n_layer=config['n_layer'],
#      44 ).to(device)
#      45 try:
# ---> 46     return train_task(model, data, config, device, data_key='complete', trial=trial)
#      47 finally:
#      48     del model
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/core/training.py:13, in train_task(model, data, param, device, data_key, trial, printing)
#      10 best_val = float('inf')
#      12 for iter in range(param['max_iters']):
# ---> 13     xb, yb = get_batch_task('train', train_data, val_data, param['batch_size'], param['block_size'], device) # Pesco tracce
#      14     logits, loss = model(xb, targets_task=yb) # Esegue il forward e predice
#      15     optimizer.zero_grad(set_to_none=True) # Reset gradienti (puliamo i calcoli del giro precedente)
#
# File /media/DATA/NickZerman/ISI-MasterDegreeThesis/utils/transformer_utils.py:25, in get_batch_task(split, train_data, val_data, batch_size, block_size, device)
#      21 data = train_data if split == 'train' else val_data
#      23 ix = torch.randint(len(data) - block_size, (batch_size,)) # Prendo batch_size indici casuali
# ---> 25 x = torch.stack([data[i:i+block_size] for i in ix])
#      26 y = torch.stack([data[i+1:i+block_size+1] for i in ix])
#      28 x,y = x.to(device), y.to(device)
#
# KeyboardInterrupt:

# %%
import optuna_variant2
study_v2_task, study_v2_time = optuna_variant2.run(n_trials=50)

# %%
import optuna_variant3
study_v3_task, study_v3_region, study_v3_time = optuna_variant3.run(n_trials=50)

# %%
import optuna_variant4
study_v4 = optuna_variant4.run(n_trials=50)

# %%
import optuna_variant5
study_v5_task, study_v5_unified = optuna_variant5.run(n_trials=50)

# %%
import optuna_variant6
study_v6 = optuna_variant6.run(n_trials=50)

# %%
print('=== RIEPILOGO BEST VAL LOSS ===')
print(f'V1  TaskTransformer:   {study_v1_task.best_value:.4f}')
print(f'V1  TimeTransformer:   {study_v1_time.best_value:.4f}')
print(f'V2  TaskTransformer:   {study_v2_task.best_value:.4f}')
print(f'V2  TimeTransformer:   {study_v2_time.best_value:.4f}')
print(f'V3  TaskTransformer:   {study_v3_task.best_value:.4f}')
print(f'V3  RegionTransformer: {study_v3_region.best_value:.4f}')
print(f'V3  TimeTransformer:   {study_v3_time.best_value:.4f}')
print(f'V4  UnifiedTransformer:{study_v4.best_value:.4f}')
print(f'V5  TaskTransformer:   {study_v5_task.best_value:.4f}')
print(f'V5  UnifiedTransformer:{study_v5_unified.best_value:.4f}')
print(f'V6  UnifiedTransformer:{study_v6.best_value:.4f}')
